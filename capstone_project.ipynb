# %% [markdown]
# <p><h4>This notebook will be used for the capstone project involving reallocation<p></h4><h4>of a person in Canada according to various
#     factors associated with it</h4>

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
